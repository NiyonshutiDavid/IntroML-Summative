# %% [markdown]
# <a href="https://colab.research.google.com/github/NiyonshutiDavid/IntroML-Summative/blob/main/Anne_Marie_Twagirayezu_Water_Quality_Notebook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import numpy as np

# %%
#LOAD THE DATA
file_id = "1PWL5QBIq4t09V-DOQeIzRnTMYUcPdZks"
download_url = f"https://drive.google.com/uc?id={file_id}"

data = pd.read_csv(download_url)
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
# plot the data

data.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

data.boxplot(figsize=(10, 10))
plt.tight_layout()
plt.show()

import seaborn as sns
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

sns.countplot(x='Potability', data=data)
plt.show()

# %%
# show how many missing values and handle them by filling in the mean

print(data.isnull().sum())
data = data.fillna(data.mean())
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
print(data.isnull().sum())
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# Plot the Data Appropriately

# %%
# generate 2d classification dataset
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

print(x)
print(y)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# 1       592.885359       15.180013        56.329076   4.500656
# 2       418.606213       16.868637        66.420093   3.055934
# 3       363.266516       18.436524       100.341674   4.628771
# 4       398.410813       11.558279        31.997993   4.075075
# ...            ...             ...              ...        ...
# 3271    526.424171       13.894419        66.687695   4.435821
# 3272    392.449580       19.903225        66.396293   2.798243
# 3273    432.044783       11.039070        69.845400   3.298875
# 3274    402.883113       11.168946        77.488213   4.708658
# 3275    327.459760       16.140368        78.698446   2.309149
#
# [3276 rows x 9 columns]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
# Split the data into training (70%), validation (15%), and testing (15%)

from sklearn.model_selection import train_test_split

x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_val_scaled = scaler.transform(x_val)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Each Member Defines their model Here

# %%
def model_annemarie():

    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],), kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(16, activation='relu', kernel_regularizer=l2(0.01)),
        Dense(1, activation='sigmoid')  # No regularization on the output layer
    ])

    #optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

    return model

model = model_annemarie()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Start the training Process

# %%
# Train the model
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    verbose=1
)

# Evaluate the model on the test set
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report

y_pred = (model.predict(X_test_scaled, verbose=0) > 0.5).astype(int)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

# Print results
print(f"\nResults:")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Not Potable', 'Potable']))
# Out:
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5556 - loss: 1.3847 - val_accuracy: 0.6293 - val_loss: 1.1435
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5872 - loss: 1.1022 - val_accuracy: 0.6314 - val_loss: 0.9401
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5984 - loss: 0.9173 - val_accuracy: 0.6314 - val_loss: 0.8180
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6086 - loss: 0.8061 - val_accuracy: 0.6314 - val_loss: 0.7475
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5957 - loss: 0.7481 - val_accuracy: 0.6314 - val_loss: 0.7084
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6031 - loss: 0.7136 - val_accuracy: 0.6314 - val_loss: 0.6872
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6008 - loss: 0.6948 - val_accuracy: 0.6314 - val_loss: 0.6752
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6084 - loss: 0.6835 - val_accuracy: 0.6314 - val_loss: 0.6703
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6085 - loss: 0.6773 - val_accuracy: 0.6314 - val_loss: 0.6652
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6269 - loss: 0.6712 - val_accuracy: 0.6477 - val_loss: 0.6640
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6009 - loss: 0.6795 - val_accuracy: 0.6477 - val_loss: 0.6601
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6323 - loss: 0.6674 - val_accuracy: 0.6497 - val_loss: 0.6567
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6290 - loss: 0.6672 - val_accuracy: 0.6497 - val_loss: 0.6532
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6194 - loss: 0.6746 - val_accuracy: 0.6517 - val_loss: 0.6465
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6473 - loss: 0.6627 - val_accuracy: 0.6925 - val_loss: 0.6439
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6494 - loss: 0.6624 - val_accuracy: 0.6762 - val_loss: 0.6398
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6731 - loss: 0.6492 - val_accuracy: 0.6701 - val_loss: 0.6386
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6702 - loss: 0.6547 - val_accuracy: 0.6884 - val_loss: 0.6346
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6548 - loss: 0.6652 - val_accuracy: 0.6721 - val_loss: 0.6320
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6505 - loss: 0.6630 - val_accuracy: 0.7067 - val_loss: 0.6308
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6562 - loss: 0.6580 - val_accuracy: 0.6802 - val_loss: 0.6313
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6423 - loss: 0.6652 - val_accuracy: 0.6945 - val_loss: 0.6297
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6743 - loss: 0.6467 - val_accuracy: 0.6823 - val_loss: 0.6273
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6656 - loss: 0.6481 - val_accuracy: 0.6802 - val_loss: 0.6275
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6756 - loss: 0.6518 - val_accuracy: 0.6925 - val_loss: 0.6304
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6729 - loss: 0.6513 - val_accuracy: 0.7067 - val_loss: 0.6348
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6842 - loss: 0.6408 - val_accuracy: 0.6884 - val_loss: 0.6251
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6616 - loss: 0.6572 - val_accuracy: 0.6945 - val_loss: 0.6246
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6765 - loss: 0.6441 - val_accuracy: 0.6843 - val_loss: 0.6253
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6675 - loss: 0.6515 - val_accuracy: 0.6843 - val_loss: 0.6265
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6641 - loss: 0.6496 - val_accuracy: 0.6843 - val_loss: 0.6282
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6633 - loss: 0.6487 - val_accuracy: 0.6986 - val_loss: 0.6283
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6757 - loss: 0.6424 - val_accuracy: 0.6762 - val_loss: 0.6274
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6722 - loss: 0.6428 - val_accuracy: 0.6782 - val_loss: 0.6262
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6769 - loss: 0.6443 - val_accuracy: 0.6945 - val_loss: 0.6243
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6664 - loss: 0.6438 - val_accuracy: 0.6741 - val_loss: 0.6291
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6845 - loss: 0.6387 - val_accuracy: 0.6884 - val_loss: 0.6279
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6840 - loss: 0.6359 - val_accuracy: 0.6986 - val_loss: 0.6317
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6645 - loss: 0.6541 - val_accuracy: 0.6965 - val_loss: 0.6218
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6698 - loss: 0.6484 - val_accuracy: 0.6945 - val_loss: 0.6253
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6745 - loss: 0.6446 - val_accuracy: 0.6904 - val_loss: 0.6257
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6729 - loss: 0.6439 - val_accuracy: 0.6925 - val_loss: 0.6225
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6862 - loss: 0.6326 - val_accuracy: 0.6925 - val_loss: 0.6214
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6902 - loss: 0.6355 - val_accuracy: 0.6904 - val_loss: 0.6223
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6798 - loss: 0.6405 - val_accuracy: 0.6843 - val_loss: 0.6237
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6628 - loss: 0.6504 - val_accuracy: 0.6864 - val_loss: 0.6236
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6659 - loss: 0.6500 - val_accuracy: 0.6945 - val_loss: 0.6215
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6659 - loss: 0.6421 - val_accuracy: 0.7026 - val_loss: 0.6275
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6805 - loss: 0.6398 - val_accuracy: 0.7047 - val_loss: 0.6231
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6806 - loss: 0.6389 - val_accuracy: 0.7006 - val_loss: 0.6282
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6656 - loss: 0.6476 - val_accuracy: 0.6823 - val_loss: 0.6239
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6904 - loss: 0.6412 - val_accuracy: 0.7006 - val_loss: 0.6237
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6897 - loss: 0.6415 - val_accuracy: 0.6965 - val_loss: 0.6254
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6952 - loss: 0.6337 - val_accuracy: 0.6843 - val_loss: 0.6222
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6605 - loss: 0.6481 - val_accuracy: 0.6884 - val_loss: 0.6210
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6725 - loss: 0.6413 - val_accuracy: 0.6945 - val_loss: 0.6252
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6669 - loss: 0.6425 - val_accuracy: 0.6986 - val_loss: 0.6229
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6805 - loss: 0.6422 - val_accuracy: 0.6925 - val_loss: 0.6227
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6616 - loss: 0.6468 - val_accuracy: 0.6802 - val_loss: 0.6229
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6586 - loss: 0.6513 - val_accuracy: 0.6884 - val_loss: 0.6211
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6623 - loss: 0.6497 - val_accuracy: 0.6986 - val_loss: 0.6210
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6891 - loss: 0.6442 - val_accuracy: 0.6986 - val_loss: 0.6216
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6784 - loss: 0.6383 - val_accuracy: 0.6741 - val_loss: 0.6244
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6787 - loss: 0.6411 - val_accuracy: 0.6884 - val_loss: 0.6243
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6778 - loss: 0.6388 - val_accuracy: 0.6762 - val_loss: 0.6233
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6664 - loss: 0.6507 - val_accuracy: 0.6904 - val_loss: 0.6212
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6980 - loss: 0.6307 - val_accuracy: 0.6802 - val_loss: 0.6241
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6895 - loss: 0.6315 - val_accuracy: 0.6843 - val_loss: 0.6240
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6778 - loss: 0.6424 - val_accuracy: 0.6802 - val_loss: 0.6241
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6818 - loss: 0.6319 - val_accuracy: 0.6823 - val_loss: 0.6237
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7003 - loss: 0.6283 - val_accuracy: 0.6762 - val_loss: 0.6232
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6980 - loss: 0.6291 - val_accuracy: 0.6904 - val_loss: 0.6203
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6700 - loss: 0.6437 - val_accuracy: 0.6823 - val_loss: 0.6228
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6841 - loss: 0.6398 - val_accuracy: 0.6925 - val_loss: 0.6293
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6806 - loss: 0.6358 - val_accuracy: 0.6945 - val_loss: 0.6247
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6826 - loss: 0.6338 - val_accuracy: 0.6843 - val_loss: 0.6222
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6755 - loss: 0.6361 - val_accuracy: 0.6904 - val_loss: 0.6236
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6826 - loss: 0.6394 - val_accuracy: 0.6762 - val_loss: 0.6235
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6885 - loss: 0.6275 - val_accuracy: 0.6904 - val_loss: 0.6282
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6662 - loss: 0.6454 - val_accuracy: 0.6823 - val_loss: 0.6229
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6774 - loss: 0.6387 - val_accuracy: 0.6864 - val_loss: 0.6288
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6950 - loss: 0.6230 - val_accuracy: 0.6864 - val_loss: 0.6241
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6899 - loss: 0.6368 - val_accuracy: 0.6904 - val_loss: 0.6269
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6815 - loss: 0.6300 - val_accuracy: 0.6884 - val_loss: 0.6250
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6816 - loss: 0.6289 - val_accuracy: 0.6884 - val_loss: 0.6232
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6943 - loss: 0.6255 - val_accuracy: 0.6925 - val_loss: 0.6261
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6874 - loss: 0.6373 - val_accuracy: 0.6904 - val_loss: 0.6225
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6885 - loss: 0.6296 - val_accuracy: 0.6864 - val_loss: 0.6222
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6901 - loss: 0.6281 - val_accuracy: 0.6823 - val_loss: 0.6236
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6782 - loss: 0.6361 - val_accuracy: 0.6884 - val_loss: 0.6209
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6740 - loss: 0.6319 - val_accuracy: 0.6884 - val_loss: 0.6207
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6575 - loss: 0.6429 - val_accuracy: 0.6762 - val_loss: 0.6232
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7003 - loss: 0.6231 - val_accuracy: 0.6823 - val_loss: 0.6264
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6800 - loss: 0.6364 - val_accuracy: 0.6823 - val_loss: 0.6247
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6652 - loss: 0.6426 - val_accuracy: 0.6823 - val_loss: 0.6238
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6596 - loss: 0.6445 - val_accuracy: 0.6904 - val_loss: 0.6240
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6769 - loss: 0.6411 - val_accuracy: 0.6904 - val_loss: 0.6199
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6996 - loss: 0.6237 - val_accuracy: 0.6762 - val_loss: 0.6231
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6741 - loss: 0.6382 - val_accuracy: 0.6884 - val_loss: 0.6191
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6915 - loss: 0.6286 - val_accuracy: 0.7006 - val_loss: 0.6185
#
# Results:
# Accuracy: 0.6870
# F1 Score: 0.4122
# Recall: 0.2919
# Precision: 0.7013
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Not Potable       0.68      0.93      0.79       307
#      Potable       0.70      0.29      0.41       185
#
#     accuracy                           0.69       492
#    macro avg       0.69      0.61      0.60       492
# weighted avg       0.69      0.69      0.65       492

# %%
#Confusion Matrix
y_pred = (model.predict(X_test_scaled) > 0.5).astype(int)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Potable', 'Potable'], yticklabels=['Not Potable', 'Potable'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
#Loss Curves
# Plot loss and accuracy curves
plt.figure(figsize=(12, 5))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
